# %% [markdown]
# #  Keras square function

# %% [markdown]
# Init library for plotting and modelling

# %%
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import numpy
from matplotlib import pyplot as plt
import numpy as np
import math
from sklearn.preprocessing import StandardScaler
from math import sqrt
from keras.models import Sequential
from keras.layers.core import Dense
from keras.wrappers.scikit_learn import KerasRegressor
# %matplotlib inline
seed = 7
numpy.random.seed(seed)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Let's demo a function

# %%
x = np.random.random((10000,1))*100-50
y=x**2
plt.plot(x, y, '.')

# %% [markdown]
# ## Let's start experimenting with keras

# %%
trainX = x
trainY = y

# %% [markdown]
# Normalize the data

# %%
print ("Shape of input: {0}".format(trainX.shape))
for i in range(5):
	print(trainX[i], trainY[i])
# Out:
# Shape of input: (10000, 1)
# [-8.68411825] [75.41390975]
# [-11.84778392] [140.36998372]
# [-7.27770306] [52.96496177]
# [40.67416517] [1654.38771245]
# [-48.41732636] [2344.23749231]

# %%
model = Sequential()
model.add(Dense(8, activation="relu"))
model.add(Dense(8, activation="relu"))
model.add(Dense(1))

# %%
import keras

sgd = keras.optimizers.SGD(lr=0.3)
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mse'])

# %%
print("Initial weights")
for layer in model.layers:
    weights = layer.get_weights() # list of numpy arrays
    print(weights)
# Out:
# Initial weights
# []
# []
# []

# %%
model.fit(trainX, trainY, validation_split=0.2, epochs=1000, batch_size=16)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/1000
# 8000/8000 [==============================] - 1s 145us/step - loss: 56.0117 - mean_squared_error: 56.0117 - val_loss: 57.3469 - val_mean_squared_error: 57.3469
# Epoch 2/1000
# 8000/8000 [==============================] - 1s 161us/step - loss: 50.8893 - mean_squared_error: 50.8893 - val_loss: 56.8022 - val_mean_squared_error: 56.8022
# Epoch 3/1000
# 8000/8000 [==============================] - 1s 128us/step - loss: 48.1157 - mean_squared_error: 48.1157 - val_loss: 43.0643 - val_mean_squared_error: 43.0643
# Epoch 4/1000
# 8000/8000 [==============================] - 2s 188us/step - loss: 48.9328 - mean_squared_error: 48.9328 - val_loss: 48.6360 - val_mean_squared_error: 48.6360
# Epoch 5/1000
# 8000/8000 [==============================] - 2s 199us/step - loss: 50.8777 - mean_squared_error: 50.8777 - val_loss: 45.2831 - val_mean_squared_error: 45.2831
# Epoch 6/1000
# ...

# %%
model.predict([40])
# Out:
# array([[1598.1663]], dtype=float32)

# %% [markdown]
# Extract weight matrix

# %%
print("Model layers: {0}".format(len(model.layers)))
for layer in model.layers:
    weights = layer.get_weights() # list of numpy arrays
    print(weights)
# Out:
# Model layers: 3
# [array([[-1.4806923 ,  0.3389592 ,  0.6261615 ,  1.0197041 , -0.44685563,
#          1.6387964 , -0.33402508,  0.3909581 ]], dtype=float32), array([ -7.11287  , -11.830755 , -12.112468 , -12.31019  , -11.082676 ,
#          3.7838695, -10.909697 , -10.636235 ], dtype=float32)]
# [array([[  0.3981809 ,  -2.512554  ,   0.3269682 ,   3.1427732 ,
#           0.62442964,   1.9152911 ,   1.3578979 ,  -1.8472419 ],
#        [ -0.39943603,   3.884833  ,  -2.2400737 ,  -1.2277584 ,
#          -0.7515705 ,  -1.4124838 ,  -1.3155959 ,   3.9283216 ],
#        [ -0.3391788 ,   3.0648317 ,  -1.3546374 ,  -2.4701152 ,
#          -1.5519149 ,  -1.4003193 ,  -1.9277956 ,   3.3973074 ],
#        [ -1.0323559 ,   2.9757411 ,  -1.0275484 ,  -1.5260162 ,
#          -2.1685479 ,  -2.296003  ,  -1.9058734 ,   3.0148463 ],
#        [ -1.5102847 ,  -1.8696079 ,  -1.6345733 ,   4.321479  ,
#          -5.4649053 ,   4.196126  ,   4.0039735 ,  -2.3861582 ],
# ...

# %%
validateX = np.linspace(-100, 100, 3000)
validateY=validateX**2
plt.plot(validateX, validateY, '.', validateX, model.predict(validateX), '.')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_5 (Dense)              (None, 8)                 16
# _________________________________________________________________
# dense_6 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 9
# ...
# Total params: 97
# Trainable params: 97
# Non-trainable params: 0
# _________________________________________________________________
